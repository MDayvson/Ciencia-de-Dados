# %% [markdown]
# # Criando uma história com os dados
# - Vamos utilizar a base disponível em:
#     - https://www.kaggle.com/datasets/olistbr/brazilian-ecommerce?select=olist_customers_dataset.csv
#     - Todos os arquivos estão disponíveis para download no link abaixo:
#         - https://drive.google.com/drive/folders/1yzu_8qvCXOzHTVTyVRTk5gdd_ki93Em4?usp=sharing

# %%
# importando a biblioteca
import os

# %%
# Guardando a pasta atual em uma variavel
pasta = os.getcwd()

# %%
# guardando os arquivos em uma variavel
arquivos = os.listdir(pasta+'/bases')
arquivos
# Out:
# ['olist_customers_dataset.csv',
#  'olist_geolocation_dataset.csv',
#  'olist_orders_dataset.csv',
#  'olist_order_items_dataset.csv',
#  'olist_order_payments_dataset.csv',
#  'olist_order_reviews_dataset.csv',
#  'olist_products_dataset.csv',
#  'olist_sellers_dataset.csv',
#  'product_category_name_translation.csv']

# %%
# importando o pandas
import pandas as pd

# %%
base = pd.read_csv(pasta+'/bases'+'/olist_orders_dataset.csv')

# %%
# visualizando a base
base.head()
# Out:
#                            order_id                       customer_id
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d  \
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15  \
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13  \
# ...

# %%
# importando o sqlite3
import sqlite3

# %%
# criando uma conexão com BD
con = sqlite3.connect('vendas.db')

# %%
# criando a tabela orders
base.to_sql('orders',con,if_exists='replace')
# Out:
# 99441

# %%
# percorrendo toda a lista de arquivos
for i in arquivos:
    print(i)
    nome_base = i.replace('.csv', '').replace('olist_','').replace('_dataset','')
    print(nome_base)
    base = pd.read_csv(pasta+'/bases'+'/'+i)
    display(base.head(3))

    base.to_sql(nome_base,con,if_exists='replace')
    
    con.commit()
# Out:
# olist_customers_dataset.csv
# customers
#                         customer_id                customer_unique_id
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0  \
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# olist_geolocation_dataset.csv
# geolocation
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng
# 0                         1037       -23.545621       -46.639292  \
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
#
#   geolocation_city geolocation_state
# ...

# %%
cur = con.cursor()

# %%
# verificando a tabela orders 
base = pd.read_csv(pasta+'/bases'+'/olist_orders_dataset.csv')

# %%
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
base.head(1)
# Out:
#                            order_id                       customer_id
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d  \
#
#   order_status order_purchase_timestamp    order_approved_at
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15  \
#
#   order_delivered_carrier_date order_delivered_customer_date
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13  \
#
#   order_estimated_delivery_date
# 0           2017-10-18 00:00:00

# %%
# fazendo o tratamento para as colunas de datas

datas = ['order_purchase_timestamp','order_approved_at','order_delivered_carrier_date','order_delivered_customer_date','order_estimated_delivery_date']

for i in datas:
    base[i] = pd.to_datetime(base[i], format='%Y-%m-%d %H:%M:%S')

# %%
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.1+ MB

# %%
# substituindo a base antiga pela nova no sql

base.to_sql('orders',con,if_exists='replace')
# Out:
# 99441

# %% [markdown]
# `Criando uma função para transformar nossa consulta em um DataFrame do Pandas`

# %%
# Fazendo uma consulta 
consulta = 'SELECT * FROM orders LIMIT 5'
resultado = cur.execute(consulta).fetchall()

# %%
# Visualizando
resultado
# Out:
# [(0,
#   'e481f51cbdc54678b7cc49136f2d6af7',
#   '9ef432eb6251297304e76186b10a928d',
#   'delivered',
#   '2017-10-02 10:56:33',
#   '2017-10-02 11:07:15',
#   '2017-10-04 19:55:00',
#   '2017-10-10 21:25:13',
#   '2017-10-18 00:00:00'),
#  (1,
#   '53cdb2fc8bc7dce0b6741e2150273451',
#   'b0830fb4747a6c6d20dea0b8c802d7ef',
#   'delivered',
#   '2018-07-24 20:41:37',
#   '2018-07-26 03:24:27',
#   '2018-07-26 14:31:00',
#   '2018-08-07 15:27:45',
#   '2018-08-13 00:00:00'),
#  (2,
#   '47770eb9100c2d0c44946d9cf07ec65d',
#   '41ce2a54c0b03bf3443c3d931a367089',
#   'delivered',
#   '2018-08-08 08:38:49',
#   '2018-08-08 08:55:23',
#   '2018-08-08 13:50:00',
#   '2018-08-17 18:06:29',
#   '2018-09-04 00:00:00'),
#  (3,
#   '949d5b44dbf5de918fe9c16f97b45f8a',
#   'f88197465ea7920adcdbec7375364d82',
#   'delivered',
#   '2017-11-18 19:28:06',
#   '2017-11-18 19:45:59',
#   '2017-11-22 13:39:59',
#   '2017-12-02 00:28:42',
#   '2017-12-15 00:00:00'),
#  (4,
# ...

# %%
# Transformando em um DataFrame
resultado = pd.DataFrame(resultado)

# %%
# visualizando o DataFrame
resultado.head(3)
# Out:
#    0                                 1                                 2
# 0  0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d  \
# 1  1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#            3                    4                    5                    6
# 0  delivered  2017-10-02 10:56:33  2017-10-02 11:07:15  2017-10-04 19:55:00  \
# 1  delivered  2018-07-24 20:41:37  2018-07-26 03:24:27  2018-07-26 14:31:00
# 2  delivered  2018-08-08 08:38:49  2018-08-08 08:55:23  2018-08-08 13:50:00
#
#                      7                    8
# 0  2017-10-10 21:25:13  2017-10-18 00:00:00
# 1  2018-08-07 15:27:45  2018-08-13 00:00:00
# 2  2018-08-17 18:06:29  2018-09-04 00:00:00

# %%
# visualizando o nome das colunas com o description
colunas = [i[0] for i in cur.description]

# %%
# atribuindo essas colunas ao dataframe

if resultado.shape[1] > 0:
    resultado.columns = colunas
resultado.head(3)
# Out:
#    index                          order_id                       customer_id
# 0      0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d  \
# 1      1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp    order_approved_at
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15  \
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13  \
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
#
#   order_estimated_delivery_date
# 0           2017-10-18 00:00:00
# 1           2018-08-13 00:00:00
# 2           2018-09-04 00:00:00

# %%
# verificando o shape do resultado
resultado.shape
# Out:
# (5, 9)

# %%
# printando o resultado
resultado
# Out:
#    index                          order_id                       customer_id
# 0      0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d  \
# 1      1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15  \
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13  \
# ...

# %%
# transformando em uma função do python

def executa_consulta(consulta):
    resultado = cur.execute(consulta).fetchall()
    resultado = pd.DataFrame(resultado)
    colunas = [i[0] for i in cur.description]
    if resultado.shape[1] > 0:
        resultado.columns = colunas
    print(resultado.shape)
    display(resultado.head(3))
    return resultado

# %%
orders = executa_consulta('SELECT * FROM	orders')
# Out:
# (99441, 9)
#    index                          order_id                       customer_id
# 0      0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d  \
# 1      1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp    order_approved_at
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15  \
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13  \
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
#
#   order_estimated_delivery_date
# 0           2017-10-18 00:00:00
# 1           2018-08-13 00:00:00
# 2           2018-09-04 00:00:00

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   index                          99441 non-null  int64
#  1   order_id                       99441 non-null  object
#  2   customer_id                    99441 non-null  object
#  3   order_status                   99441 non-null  object
#  4   order_purchase_timestamp       99441 non-null  object
#  5   order_approved_at              99281 non-null  object
#  6   order_delivered_carrier_date   97658 non-null  object
#  7   order_delivered_customer_date  96476 non-null  object
#  8   order_estimated_delivery_date  99441 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 6.8+ MB
